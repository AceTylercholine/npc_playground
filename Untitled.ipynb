# %%
import matplotlib.pyplot as plt

# Data to plot
labels = ['Multi-Event', 'Comp Win', 'No Comp Win', 'Comp Lose', 'No Comp Lose']
sizes = [11, 6, 11, 24, 9]
colors = ['#514D67', '#003074', '#4d7dc1', '#551d0b', '#a16958']

# Plot
plt.pie(sizes, labels=labels, colors=colors,
autopct=lambda p: '{:.0f}\n({:.1f}%)'.format(p * sum(sizes) / 100, p), startangle=0)

plt.axis('equal')
plt.title('Distribution of Categories')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = ['Multi-Event', 'Comp Win', 'No Comp Win', 'Comp Lose', 'No Comp Lose']
sizes = [11, 6, 11, 24, 9]
colors = ['#514D67', '#003074', '#4d7dc1', '#551d0b', '#a16958']

# Plot
plt.pie(sizes, labels=labels, colors=colors,
autopct=lambda p: '{:.0f}\n({:.1f}%)'.format(p * sum(sizes) / 100, p), startangle=90, counterclock=False)

plt.axis('equal')
plt.title('Distribution of Categories')
plt.show()

# %%
11+6+11+24+9
# Out:
# 61

# %%
11/61
# Out:
# 0.18032786885245902

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = ['Multi-Event', 'Comp Win', 'No Comp Win', 'Comp Lose', 'No Comp Lose']
sizes = [11, 6, 11, 24, 9]
colors = ['#514D67', '#003074', '#4d7dc1', '#551d0b', '#a16958']

# Plot
plt.pie(sizes, labels=labels, colors=colors,
        autopct=lambda p: '{:.0f}\n({:.1f}%)'.format(p * sum(sizes) / 100, p),
        startangle=90, counterclock=False, textprops={'fontsize': 24, 'color': 'white'})

plt.axis('equal')
# plt.title('Distribution of Categories')  # Removed title
plt.show()

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = ['Multi-Event', 'Competitive Win', 'Non-competitive Win', 'Competitive Loss', 'Non-competitive Loss']
sizes = [11, 6, 11, 24, 9]
colors = ['#514D67', '#003074', '#4d7dc1', '#551d0b', '#a16958']

# Plot
plt.pie(sizes, labels=labels, colors=colors,
        autopct=lambda p: '{:.0f}\n({:.1f}%)'.format(p * sum(sizes) / 100, p),
        startangle=90, counterclock=False, textprops={'fontsize': 16, 'color': 'black'})

# Get the patches and texts of the pie chart
patches, texts, autotexts = plt.pie(sizes, colors=colors, autopct=lambda p: '{:.0f}\n({:.1f}%)'.format(p * sum(sizes) / 100, p), startangle=90, counterclock=False, textprops={'fontsize': 16})

# Set the color of the autotexts (percentage and count) to white
for autotext in autotexts:
    autotext.set_color('white')

plt.axis('equal')
plt.savefig('sig_units.jpg', format='jpg', bbox_inches='tight')
plt.show()
