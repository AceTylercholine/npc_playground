# %%
putatives = pd.read_pickle(r"./Newest_UMAP/umap_df_detail.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 putatives = pd.read_pickle(r"./Newest_UMAP/umap_df_detail.pkl")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import ast
import pickle
from pathlib import Path
import matplotlib.pyplot as plt
import multirecording_spikeanalysis as spike

# %%
putatives = pd.read_pickle(r"./Newest_UMAP/umap_df_detail.pkl")

# %%
putatives
# Out:
#               x          y                                           waveform  \
# 0     11.056281   6.725037  [0.1099006, 0.116567135, 0.12440342, 0.1342621...
# 1      4.670065   5.406483  [0.068219796, 0.072843686, 0.07739481, 0.08312...
# 2      9.244576   7.548844  [0.09019028, 0.09590861, 0.10189682, 0.1097604...
# 3      7.081917   5.954050  [0.084707275, 0.09079722, 0.095418565, 0.10189...
# 4      8.892169   3.198857  [0.060261134, 0.06250456, 0.064926274, 0.06951...
# ...         ...        ...                                                ...
# 1023   8.960026   7.276891  [0.082149416, 0.08867837, 0.09511313, 0.102331...
# 1024   6.746817   2.921816  [-0.020411404, -0.021038724, -0.021981757, -0....
# 1025   9.150778   7.406654  [0.09007283, 0.09648524, 0.10219027, 0.1087899...
# 1026  10.318449  10.482354  [0.116127074, 0.12621383, 0.13441177, 0.141879...
# 1027   7.488008   9.815981  [0.07765363, 0.08082476, 0.083958745, 0.087227...
#
#       cluster_id                     cluster_color  firing_rate  \
# 0              6    [0.8538, 0.2217, 0.02677, 1.0]     4.813648
# 1              1  [0.27698, 0.46153, 0.93309, 1.0]     0.820515
# 2              7   [0.4796, 0.01583, 0.01055, 1.0]     0.843159
# 3              0  [0.18995, 0.07176, 0.23217, 1.0]     1.958041
# 4              3  [0.38127, 0.98909, 0.42386, 1.0]     7.644411
# ...          ...                               ...          ...
# 1023           7   [0.4796, 0.01583, 0.01055, 1.0]    11.014126
# 1024           3  [0.38127, 0.98909, 0.42386, 1.0]     4.094002
# 1025           7   [0.4796, 0.01583, 0.01055, 1.0]     1.999230
# 1026           6    [0.8538, 0.2217, 0.02677, 1.0]     0.862059
# 1027           4  [0.82333, 0.91253, 0.20663, 1.0]     8.029597
#
#                                          recording_name  unit_id
# 0     20240320_142408_alone_comp_subj_3-3_t5b5_merge...     45.0
# 1     20240320_142408_alone_comp_subj_3-3_t5b5_merge...     60.0
# 2     20240320_142408_alone_comp_subj_3-3_t5b5_merge...     67.0
# 3     20240320_142408_alone_comp_subj_3-3_t5b5_merge...    109.0
# 4     20240320_142408_alone_comp_subj_3-3_t5b5_merge...    124.0
# ...                                                 ...      ...
# 1023  20240409_142051_comp_novel_subj_3-4_t4b4_merge...    236.0
# 1024  20240409_142051_comp_novel_subj_3-4_t4b4_merge...    238.0
# 1025  20240409_142051_comp_novel_subj_3-4_t4b4_merge...    243.0
# 1026  20240409_142051_comp_novel_subj_3-4_t4b4_merge...    269.0
# 1027  20240409_142051_comp_novel_subj_3-4_t4b4_merge...    277.0
#
# [1028 rows x 8 columns]
